# %% [markdown]
# <h1 style="background-color:brown;color:gold;text-align:center">Estructuras condicionales</h1>

# %% [markdown]
# <h1 style="text-transform:uppercase"><b>determinar par</b></h1>
# <div style="box-sizing:border-box;width:100ch;height:auto">
#     <p>
#     Escriba un programa que determine si el número entero ingresado por el usuario es par o no.
#     </p>
#     <div style="box-sizing:border-box;display:flex;flex-direction:column;flex:0 0 auto">
#         <div style="box-sizing:border-box;background-color:white;color:black;border:1px solid black;width:fit-content;flex:1 1 auto;font-family:'Consolas', 'Deja Vu Sans Mono', 'Bitstream Vera Sans Mono', monospace;margin:2ch">
#             <p style="margin: 1ch">
#                 Ingrese un número: <b>4</b><br>
#                 Su número es par
#             </p>
#         </div>
#         <div style="box-sizing:border-box;background-color:white;color:black;border:1px solid black;width:fit-content;flex:1 1 auto;font-family:'Consolas', 'Deja Vu Sans Mono', 'Bitstream Vera Sans Mono', monospace;margin:2ch">
#             <p style="margin: 1ch">
#                 Ingrese un número: <b>3</b><br>
#                 Su número es impar
#             </p>
#         </div>
#     </div>
# </div>

# %%
def determinar_par():
    numero=input("Ingrese un número: \n")

# %% [markdown]
# <h1 style="text-transform:uppercase"><b>BOILERPLATE</b></h1>
# <div style="box-sizing:border-box;width:100ch;height:auto">
#     <p>
#     DESCRIPCION
#     </p>
#     <div style="box-sizing:border-box;display:flex;flex-direction:column;flex:0 0 auto">
#         <div style="box-sizing:border-box;background-color:white;color:black;border:1px solid black;width:fit-content;flex:1 1 auto;font-family:'Consolas', 'Deja Vu Sans Mono', 'Bitstream Vera Sans Mono', monospace;margin:2ch">
#             <p style="margin: 1ch">
#                 Cuadro 1
#             </p>
#         </div>
#         <div style="box-sizing:border-box;background-color:white;color:black;border:1px solid black;width:fit-content;flex:1 1 auto;font-family:'Consolas', 'Deja Vu Sans Mono', 'Bitstream Vera Sans Mono', monospace;margin:2ch">
#             <p style="margin: 1ch">
#                 Cuadro 2
#             </p>
#         </div>
#     </div>
# </div>

# %% [markdown]
# <h1 style="text-transform:uppercase"><b>BOILERPLATE</b></h1>
# <div style="box-sizing:border-box;width:100ch;height:auto">
#     <p>
#     DESCRIPCION
#     </p>
#     <div style="box-sizing:border-box;display:flex;flex-direction:column;flex:0 0 auto">
#         <div style="box-sizing:border-box;background-color:white;color:black;border:1px solid black;width:fit-content;flex:1 1 auto;font-family:'Consolas', 'Deja Vu Sans Mono', 'Bitstream Vera Sans Mono', monospace;margin:2ch">
#             <p style="margin: 1ch">
#                 Cuadro 1
#             </p>
#         </div>
#         <div style="box-sizing:border-box;background-color:white;color:black;border:1px solid black;width:fit-content;flex:1 1 auto;font-family:'Consolas', 'Deja Vu Sans Mono', 'Bitstream Vera Sans Mono', monospace;margin:2ch">
#             <p style="margin: 1ch">
#                 Cuadro 2
#             </p>
#         </div>
#     </div>
# </div>
